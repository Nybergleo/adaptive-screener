# %% [markdown]
# # Adaptive Screener
#
# Reusable adaptive Bloomberg BQL screen for configurable input filters and output fields.

# %%
# %load_ext autoreload
# %autoreload 2

from adaptive_screener_app import AdaptiveScreenerApp

AdaptiveScreenerApp().show()
