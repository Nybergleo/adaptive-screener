# %% [markdown]
# # Western Europe Margin Stability Screener
#
# Reusable Bloomberg BQL screen for EBIT margin, EBITA margin, quarterly margin stability, P/E, and absolute EBIT.

# %%
# %load_ext autoreload
# %autoreload 2

from margin_stability_screener_app import MarginStabilityScreenerApp

MarginStabilityScreenerApp().show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
# Output()
# Output()
# Output()
